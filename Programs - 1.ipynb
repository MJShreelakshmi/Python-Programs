# %%
# Leap Year
def is_leap(year):
    # Write your logic here
    if year % 4 == 0:
        if year % 400==0 or year % 100 != 0:
            leap = True
        else:
            leap = False
    else:
        leap = False
    return leap

year = int(input())
print(is_leap(year))
# Out:
# 2025
# False

# %% [markdown]
# #### 2) Without using any string methods, try to print the following: 123...n
#
# Note that "..." represents the consecutive values in between.
# Example: n = 5
# Print the string 12345

# %%
n = int(input())
# Out:
# 5

# %%
for i in range(1,n+1):
    print(i, end = '')
# Out:
# 12345

# %%
''.join(str(i) for i in range(1,n+1))
# Out:
# '12345'

# %%
s = ''
for i in range (1,n+1):
    s = s+str(i)
print(s)
# Out:
# 12345

# %% [markdown]
# #### 3) Task

# %% [raw]
# s = 'AAABCADDE'
# k = 3
# There are three substrings of length  to consider: 'AAA', 'BCA' and 'DDE'. The first substring is all 'A' characters, so u1 = 'A'. The second substring has all distinct characters, so u2 = 'BCA'. The third substring has  different characters, so u3 = 'DE'. Note that a subsequence maintains the original order of characters encountered. The order of characters in each subsequence shown is important.
#
# Function Description
#
# Complete the merge_the_tools function in the editor below.
#
# merge_the_tools has the following parameters:
#
# string s: the string to analyze
# int k: the size of substrings to analyze
# Prints
#
# Print each subsequence on a new line. There will be (n/k) of them. No return value is expected.
#
# Input Format
#
# The first line contains a single string, s.
# The second line contains an integer,k , the length of each substring.

# %%
str_ = 'AAABCADDE'
k=3
def merge_the_tools(str_, k)
    l = []
    for i in range(len(str_)):
        if (i+1)%k==0:
            l.append(str_[i-k+1:i+1])
    for sub in l:
        u = ''
        for s in sub:
            if s not in u:
                u+=s
        print(u)
# Out:
# A
# BCA
# DE

# %%
def merge_the_tools(string, k):
    # your code goes here
    l=[]
    for i in range(len(string)):
        if (i+1)% k == 0:
            l.append(string[i-k+1:i+1])
    for sub in l:
        u = ''
        for s in sub:
            if s not in u:
                u+=s
        print(u)

# %%
string = '...'
k = 1246
merge_the_tools(string, k)
# Out:
# RDITWGZKCEXNHSAUJYOFQMPVBL
# DOVIKJPRGYHZQXBMEUALCTSWFN
# JBCLGFUSTDOKYIRZVAEXPWMQNH
# OQNIBFLHXZSRJMDETWGYVPUACK
# LBSTKUYVHMZQAXGJPCNOEWDIRF
# OYPZVRFKDEUQSIBAXGLJWMNCHT
# WRDSMQIGZXHEOBACFNVUKJPYTL
# EDQNUKVBRSLGWZOAMXIHJYCTFP

# %% [markdown]
# #### 4) Minion Game

# %% [raw]
# Kevin and Stuart want to play the 'The Minion Game'.
# Game Rules:
# Both players are given the same string, S.
# Both players have to make substrings using the letters of the string S.
# Stuart has to make words starting with consonants.
# Kevin has to make words starting with vowels.
# The game ends when both players have made all possible substrings.
#
# Scoring
# A player gets +1 point for each occurrence of the substring in the string .
#
# For Example:
# String S = BANANA
# Kevin's vowel beginning word = ANA
# Here, ANA occurs twice in BANANA. Hence, Kevin will get 2 Points.
#
# Your task is to determine the winner of the game and their score.
# minion_game has the following parameters:
# string: the string to analyze
# Prints:-
# string: the winner's name and score, separated by a space on one line, or Draw if there is no winner
# Input Format
#
# A single line of input containing the string S.
# Note: The string  will contain only uppercase letters: [A-Z].

# %%
# doesnot satisfy all test cases bcz of the CPU overload
kv = {}
st = {}
s = 'BANANA'
for i in range(len(s)):
    if s[i] in 'AEIOU':
        d = kv
    else:
        d = st
    for j in range(i,len(s)):
        if s[i:j+1] not in d:
            d[s[i:j+1]] = 1   
        else:
            d[s[i:j+1]] += 1 
            
print(kv)
print(st)
if sum(kv.values())>sum(st.values()):
    print('Kevin', sum(kv.values()))
else:
    print('Stuart', sum(st.values()))
# Out:
# {'A': 3, 'AN': 2, 'ANA': 2, 'ANAN': 1, 'ANANA': 1}
# {'B': 1, 'BA': 1, 'BAN': 1, 'BANA': 1, 'BANAN': 1, 'BANANA': 1, 'N': 2, 'NA': 2, 'NAN': 1, 'NANA': 1}
# Stuart 12

# %%
def minion_game(string):
    vowels = 'AEIOU'
    kevin_score = 0
    stuart_score = 0
    length = len(string)

    for i in range(length):
        # Calculate score based on starting letter
        if string[i] in vowels:
            kevin_score += length - i
        else:
            stuart_score += length - i

    # Determine and print the winner
    if kevin_score > stuart_score:
        print(f"Kevin {kevin_score}")
    elif stuart_score > kevin_score:
        print(f"Stuart {stuart_score}")
    else:
        print("Draw")

# Example usage
minion_game("BANANA")
# Out:
# Stuart 12

# %%
string = '...'
minion_game(string)
# Out:
# Kevin 400173457964

# %%
def fibo(n):
    a=0
    b=1
    print(a,b, end = ' ')
    for i in range(n):
        c = a+b
        a,b = b,c
        print(c, end = ' ')
fibo(5)
# Out:
# 0 1 1 2 3 5 8

# %%
cube = lambda x: x**3
print(list(map(cube, fibo(5))))  # bcz fibo returns Nonetype
# Note: only functns with return values can be used along with map
# Out:
# 0 1 1 2 3 5 8
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 2
#       1 cube = lambda x: x**3
# ----> 2 print(list(map(cube, fibo(5))))
#
# TypeError: 'NoneType' object is not iterable

# %%
l = []
n = int(input())
def fibo(n):
    a=0
    b=1
    if n == 0:
        return l
    elif n==1:
        l.append(a)
        return l
    else:
        l.extend((a,b))
        for i in range(n):
            c = a+b
            a,b = b,c
            l.append(c)
    return l
# fibo(5)
cube = lambda x: x**3
print(list(map(cube, fibo(n))))
# Out:
# 5
# [0, 1, 1, 8, 27, 125, 512]

# %%
def fun(s):
    # return True if s is a valid email, else return False
    try:
        user_name = s.split('@',1)[0]      
        for i in user_name:
            if not i.isalnum(): 
                if i not in '_-':
                    return False

        website_name = s.split('@',1)[1].split('.')[0]
        for i in website_name:
            if not i.isalnum():
                return False

        extension = s.split('@',1)[1].split('.')[1]  
        if len(extension)>3 and len(extension)<0 and not extension.isalpha():
            return False
        return True
        extension = s.split('@',1)[1].split('.')[1]  
    except IndexError as e:
        return False

def filter_mail(emails):
    return list(filter(fun, emails))

if __name__ == '__main__':
    n = int(input())
    emails = []
    for _ in range(n):
        emails.append(input())

filtered_emails = filter_mail(emails)
filtered_emails.sort()
print(filtered_emails)
# Out:
# 5
# its@gmail.com1
# mike13445@yahoomail9.server
# rase23@ha_ch.com
# daniyal@gmail.coma
# thatisit@thatisit
# ['daniyal@gmail.coma', 'its@gmail.com1', 'mike13445@yahoomail9.server']

# %%
s='shree-lakshmi_@gmail.com'
fun(s)
# Out:
# True

# %%
def fun(s):
    # return True if s is a valid email, else return False
    try:
        user_name = s.split('@',1)[0] 
        
        for i in user_name:
            if not i.isalnum(): 
                if i not in '_-':
                    return False

        website_name = s.split('@',1)[1].split('.')[0]
        for i in website_name:
            if not i.isalnum():
                return False

        extension = s.split('@',1)[1].split('.')[1]  
        if len(extension)>3 or len(extension)<0 and not extension.isalpha():
            return False
        return True
        extension = s.split('@',1)[1].split('.')[1]  
    except IndexError as e:
        return False

def filter_mail(emails):
    return list(filter(fun, emails))

if __name__ == '__main__':
    n = int(input())
    emails = []
    for _ in range(n):
        emails.append(input())

filtered_emails = filter_mail(emails)
filtered_emails.sort()
print(filtered_emails)
# Out:
# 5
# itsme@gmail
# @something
# @something
# @something.co1
# sone.com
# co1
# ['@something.co1']

# %%
s = '@something.co1'
s.split('@')
# Out:
# ['', 'something.co1']
